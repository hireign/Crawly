# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
global domainName
global rootURL
global alternativeURLs
domainRegex = re.compile(r"https?://?(www\.)?")

# %% [markdown]
# ### To format any url to http://www. format and eliminate other alternatives

# %%
def URLFormatter(url):
    formattedURL = domainRegex.sub('', url).strip().strip('/')
    formattedURL = re.sub("www.", "", formattedURL)
    formattedURL = 'http://www.' + formattedURL
    return formattedURL
# URLFormatter("//domain.com/home")

# %% [markdown]
# ### Fetching homepage of the website

# %%
# Ads http:// to the given URL because it is the only way to check for server response
# If the user will add to the URL directions then they will be deleted
# Example: 'https://moz.com/learn/seo/external-link' will turn to 'https://moz.com/'
# https://stackoverflow.com/questions/32314304/check-if-an-url-is-relative-to-another-ie-they-are-on-the-same-host

rootURL = "https://srath.com/"
domainName = URLFormatter(rootURL)
rootURL = domainName.split('/')[0] + "//" + domainName.split('/')[2]
source_code = requests.get(rootURL)
status_code = source_code.status_code
if(status_code != 200):
    source_code = requests.get(rootURL, headers={"User-Agent": "XY"})
soup = BeautifulSoup(source_code.text, "lxml")
rootTitle = soup.find("title").text
print("fetched "+rootURL+" status code: "+str(status_code))
# Out:
# fetched http://www.srath.com status code: 200

# %%
def alternativeURLCreator(url):
    noPrefix = domainRegex.sub('', url).strip().strip('/')
    noPrefix = re.sub("www.", "", noPrefix)
    alternativeURLs = []
    alternativeURLs.append(noPrefix)
    alternativeURLs.append("http://"+noPrefix)
    alternativeURLs.append("http://"+noPrefix+"/")
    alternativeURLs.append("http://"+noPrefix+"//")
    alternativeURLs.append("https://"+noPrefix)
    alternativeURLs.append("https://"+noPrefix+"/")
    alternativeURLs.append("https://"+noPrefix+"//")
    alternativeURLs.append("http://www."+noPrefix)
    alternativeURLs.append("http://www."+noPrefix+"/")
    alternativeURLs.append("http://www."+noPrefix+"//")
    alternativeURLs.append("https://www."+noPrefix)
    alternativeURLs.append("https://www."+noPrefix+"/")
    alternativeURLs.append("https://www."+noPrefix+"//")
    alternativeURLs.append("//"+noPrefix)
    alternativeURLs.append("//"+noPrefix+"/")
    alternativeURLs.append("//"+noPrefix+"//")
    alternativeURLs.append("//www."+noPrefix)
    alternativeURLs.append("//www."+noPrefix+"/")
    alternativeURLs.append("//www."+noPrefix+"//")
    return alternativeURLs

# %%
alternativeDomains = alternativeURLCreator(rootURL)
print(alternativeDomains)
# Out:
# ['srath.com', 'http://srath.com', 'http://srath.com/', 'http://srath.com//', 'https://srath.com', 'https://srath.com/', 'https://srath.com//', 'http://www.srath.com', 'http://www.srath.com/', 'http://www.srath.com//', 'https://www.srath.com', 'https://www.srath.com/', 'https://www.srath.com//', '//srath.com', '//srath.com/', '//srath.com//', '//www.srath.com', '//www.srath.com/', '//www.srath.com//']

# %%
def commonURLChecker(url):
    a = alternativeURLCreator(url)
    b = urlList
    common = list(set(a) & set(b))
    common = str(common).strip("[]").strip('\'')
    return common

# %%
externalURLKeywords = ["http", "www", ".com", "https"]
exceptions = ["#", " ", "tel:", "callto:", "mailto:", "wp-content", "wp-login", ".pdf", "twitter.com", "facebook.com", "google.com", "pinterest.com", ".jpg", ".jpeg", ".webm", "javascript:void", "/out/", "?share="]

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
def urlCrawler(url, current_page, max_pages):
    global pageCount
    pageCount += 1
    tempTargetList = []
    outgoing_links = 0
    print("\n\n"+color.BLUE+color.BOLD+"now crawling page: "+color.END+url)
#     Fetching Data
    try:
        source_code = requests.get(url)
    except:
        status_code = source_code.status_code
        print(color.BLUE+color.BOLD+"status code: "+color.END+str(status_code))
    else:
        status_code = source_code.status_code
        print(color.BLUE+color.BOLD+"status code: "+color.END+""+str(status_code))
    if(source_code.status_code != 200):
        source_code = requests.get(rootURL, headers={"User-Agent": "XY"})
        status_code = source_code.status_code
        print(color.BLUE+color.BOLD+"new status code: "+color.END+str(status_code))
#     source_code = requests.get(url)
    if(status_code == 200):
#         not sure whether to keep the above if statement or not. The code works perfectly without it too
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        a = soup.findAll("a")
    #     Assiging Page Data to Dictionary
        if url not in pageDict:
            pageDict[""+url+""] = {}
        data = pageDict[""+url+""]
        try:
            data['title'] = soup.find("title").text
        except:
            print("error: title could not be found")
        data['status_code'] = status_code
        if(url == rootURL): 
            data['clickDepth'] = 0
            data["incoming_links"] = 0
        cur_clickDepth = data['clickDepth']
    #     Run a loop to find target urls
        for eachURL in a:
            href = eachURL.get("href")
            if(eachURL.get("title")):
                anchor = eachURL.get("title")
                anchor = anchor.replace("\n", "").strip()
            else:
                anchor = eachURL.text
                anchor = anchor.replace("\n", "").strip()
            if(href):
                if not any(x in href for x in exceptions):
#                 if any(x in href for x in alternativeURLs) and not any(x in href for x in exceptions):
#                 if not any(x in href for x in alternativeURLs) and not any(x in href for x in exceptions):
    #                 need to change above if statement. Works perfectly for with any x for puppywire.com and with not any x for hotelhalifax.ca but does not work in the alternative case for both
                    if (href == "/" or href in alternativeDomains):
                        tempURL = rootURL
                        tempURL = URLFormatter(tempURL)
                        print("\nfound "+href+" = "+tempURL+" for href in alternativeDomains")
                    elif any(href.startswith(x) for x in alternativeDomains):
                        tempURL = href
                        tempURL = URLFormatter(tempURL)
                        print("\nfound "+href+" = "+tempURL+" for href.startswith(x) for x in alternativeDomains")
                    elif(len(href)>1 and href[0] == "/" and not any(x in href for x in externalURLKeywords)):
                        tempURL = rootURL+""+href
                        tempURL = URLFormatter(tempURL)
                        print("\nfound "+href+" = "+tempURL+" for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords")
                    elif any(x in href for x in externalURLKeywords):
                        tempURL = ""
                        print(color.RED+color.BOLD+"\ndeclined external URL "+color.END+href)
                    else:
#                         added for URLs like "music.html"
                        tempURL = rootURL+"/"+href
                        tempURL = URLFormatter(tempURL)
                        print("\nfound "+href+" = "+tempURL+" for else")
                    if(tempURL!="" and tempURL not in tempTargetList and tempURL != url):
                        sourceList.append(url)
                        targetList.append(tempURL)
                        anchorList.append(anchor)
                        hrefList.append(href)
                        print(color.BOLD+"for source: "+color.END+url+color.BOLD+" , appending target: "+color.END+tempURL+color.BOLD+" , anchor: "+color.END+anchor)
                        outgoing_links += 1
                        tempTargetList.append(tempURL)
                        if (tempURL not in urlList):
                            if not any(x in alternativeURLCreator(tempURL) for x in urlList):  
#                       checking if triggered url is a new one and appending ot the urllist if affirmative
                                urlList.append(tempURL)
                                pageDict[""+tempURL+""] = {}                            
                                pageDict[""+tempURL+""]['clickDepth'] = cur_clickDepth+1
                                pageDict[""+tempURL+""]["incoming_links"] = 1
                                print(color.GREEN+color.BOLD+"appending new url: "+color.END+tempURL+color.BOLD+" click depth: "+color.END+str(pageDict[""+tempURL+""]['clickDepth']))
                            else:
                                duplicateURL = commonURLChecker(tempURL)
                                pageDict[""+duplicateURL+""]["incoming_links"] += 1
                                print("URL already in URLlist")
                        else:
                            pageDict[""+tempURL+""]["incoming_links"] += 1
                            print("URL already in URLlist")
                    elif(tempURL!=""):
                        print(color.RED+color.BOLD+"duplicate target link"+color.END)
                else:
                    print(color.RED+color.BOLD+"\ndeclined url (href in exceptions): "+color.END+""+href)
        if(pageCount < max_pages and pageCount < len(urlList)): 
            data['outgoing_links'] = outgoing_links
            urlCrawler(urlList[pageCount], pageCount, max_pages)
        else:
            data['outgoing_links'] = outgoing_links
    else:
#         skeptical about this else statement too. it is meant to add rows for URLs failed to fetch
        if url not in pageDict:
            pageDict[""+url+""] = {}
        data = pageDict[""+url+""]
        data['status_code'] = status_code
        print(color.RED+color.BOLD+"failed to crawl: "+color.END+url+color.BOLD+" status code: "+color.END+status_code)
        if(pageCount < max_pages and pageCount < len(urlList)): 
            data['outgoing_links'] = outgoing_links
            urlCrawler(urlList[pageCount], pageCount, max_pages)
        else:
            data['outgoing_links'] = outgoing_links

# %%
pageDict = {}
pageCount = 0

sourceList = []
targetList = []
anchorList = []
hrefList = []

urlList = [rootURL]
outgoing_links = 0
import time
start_time = time.time()
urlCrawler(rootURL, 0, 10)
time = (time.time() - start_time)
print("--- %s seconds ---"%time)
# Out:
# now crawling page: http://www.srath.com
# status code: 200
#
# declined external URL http://srijagannath.org/
#
# declined url (href in exceptions): #
#
# declined external URL http://sohamsa.com
#
# declined url (href in exceptions): #
#
# declined external URL http://sohamsa.in/
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://thejyotishdigest.com/
#
# declined external URL http://vyasadeva.com
#
# declined external URL http://devaguru.com
#
# declined url (href in exceptions): #
#
# declined external URL http://jaiminisutra.com
#
# declined external URL http://srath.info
#
# declined external URL http://parasarahora.com
#
# declined external URL http://mantrashastra.com
#
# declined external URL http://srath.info
#
# declined external URL http://deva.guru/
#
# declined url (href in exceptions): #
#
# declined external URL http://deva.guru/panchang
#
# declined external URL http://deva.guru/muhurta/
#
# declined url (href in exceptions): https://srath.com/wp-login.php
#
# declined url (href in exceptions): https://srath.com/wp-login.php?action=lostpassword
#
# declined url (href in exceptions): https://srath.com/wp-login.php?action=register
#
# found https://srath.com = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# found https://srath.com = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# found https://srath.com/ = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/about/ = http://www.srath.com/category/about for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category
href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta , anchor: Muhurta
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta click depth: 1
#
# found https://srath.com/category/jyoti%e1%b9%a3a/mundane/ = http://www.srath.com/category/jyoti%e1%b9%a3a/mundane for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/mundane , anchor: Mundane
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/mundane click depth: 1
#
# found https://srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra/ = http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra , anchor: Nakṣatra
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra click depth: 1
#
# found https://srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga , anchor: Pañcāṅga
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga click depth: 1
#
# found https://srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa/ = http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa , anchor: Tithī Praveśa
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa click depth: 1
#
# found https://srath.com/category/jyoti%e1%b9%a3a/varga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/varga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/varga , anchor: Varga
# appending new url: http://www.srath.com/category/jyoti%e1%b9%a3a/varga click depth: 1
#
# found https://srath.com/category/misc/jyoti%e1%b9%a3a-gems/ = http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems , anchor: Jyotiṣa Gems
# appending new url: http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems click depth: 1
#
# found https://srath.com/category/misc/vastu/ = http://www.srath.com/category/misc/vastu for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/vastu , anchor: Vāstu
# appending new url: http://www.srath.com/category/misc/vastu click depth: 1
#
# found https://srath.com/category/learn/ = http://www.srath.com/category/learn for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/learn , anchor: Learn
# appending new url: http://www.srath.com/category/learn click depth: 1
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/announcements/ = http://www.srath.com/category/announcements for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/announcements , anchor: Announcements
# appending new url: http://www.srath.com/category/announcements click depth: 1
#
# found https://srath.com/category/learn/workshops/ = http://www.srath.com/category/learn/workshops for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/learn/workshops , anchor: Workshops
# appending new url: http://www.srath.com/category/learn/workshops click depth: 1
#
# found https://srath.com/category/spirituality/ = http://www.srath.com/category/spirituality for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/spirituality , anchor: Spirit
# appending new url: http://www.srath.com/category/spirituality click depth: 1
#
# found https://srath.com/category/misc/ = http://www.srath.com/category/misc for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc , anchor: Misc
# appending new url: http://www.srath.com/category/misc click depth: 1
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/misc/media/video/ = http://www.srath.com/category/misc/media/video for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/media/video , anchor: Video
# appending new url: http://www.srath.com/category/misc/media/video click depth: 1
#
# found https://srath.com/category/misc/media/ = http://www.srath.com/category/misc/media for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/media , anchor: Media
# appending new url: http://www.srath.com/category/misc/media click depth: 1
#
# found https://srath.com/category/misc/raphsody/ = http://www.srath.com/category/misc/raphsody for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/raphsody , anchor: Raphsody
# appending new url: http://www.srath.com/category/misc/raphsody click depth: 1
#
# found https://srath.com/category/misc/resources/ = http://www.srath.com/category/misc/resources for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/misc/resources , anchor: Resources
# appending new url: http://www.srath.com/category/misc/resources click depth: 1
#
# found https://srath.com/category/your-futurology/ = http://www.srath.com/category/your-futurology for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/category/your-futurology , anchor: Your Futurology
# appending new url: http://www.srath.com/category/your-futurology click depth: 1
#
# declined url (href in exceptions): #
#
# found https://srath.com/about-future/ = http://www.srath.com/about-future for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/about-future , anchor: About Your Future
# appending new url: http://www.srath.com/about-future click depth: 1
#
# found https://srath.com/the-process/ = http://www.srath.com/the-process for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/the-process , anchor: The Process
# appending new url: http://www.srath.com/the-process click depth: 1
#
# found https://srath.com/standard-60min/ = http://www.srath.com/standard-60min for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/standard-60min , anchor: Standard 60min
# appending new url: http://www.srath.com/standard-60min click depth: 1
#
# found https://srath.com/quick-consult/ = http://www.srath.com/quick-consult for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/quick-consult , anchor: Short Meeting 30m
# appending new url: http://www.srath.com/quick-consult click depth: 1
#
# found https://srath.com/standard-india/ = http://www.srath.com/standard-india for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/standard-india , anchor: Standard India 60m
# appending new url: http://www.srath.com/standard-india click depth: 1
#
# found https://srath.com/quick-india-consult/ = http://www.srath.com/quick-india-consult for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/quick-india-consult , anchor: Short India 30m
# appending new url: http://www.srath.com/quick-india-consult click depth: 1
#
# declined url (href in exceptions): #g-search-search-4417
#
# declined url (href in exceptions): mailto:rathreadings@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined external URL https://api.whatsapp.com/send?phone=919818593935
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# found https://srath.com/files/reading/vedic_reading_form.rtf = http://www.srath.com/files/reading/vedic_reading_form.rtf for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/files/reading/vedic_reading_form.rtf , anchor: Rich Text Format
# appending new url: http://www.srath.com/files/reading/vedic_reading_form.rtf click depth: 1
#
# found https://srath.com/files/reading/vedic_reading_form.doc = http://www.srath.com/files/reading/vedic_reading_form.doc for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/files/reading/vedic_reading_form.doc , anchor: Word - DOC
# appending new url: http://www.srath.com/files/reading/vedic_reading_form.doc click depth: 1
#
# found https://srath.com/files/reading/vedic_reading_form.docx = http://www.srath.com/files/reading/vedic_reading_form.docx for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/files/reading/vedic_reading_form.docx , anchor: Word - DOCX
# appending new url: http://www.srath.com/files/reading/vedic_reading_form.docx click depth: 1
#
# found https://srath.com/msp-ii-graha-devata/ = http://www.srath.com/msp-ii-graha-devata for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/msp-ii-graha-devata , anchor: MSP-II Graha Devata
# appending new url: http://www.srath.com/msp-ii-graha-devata click depth: 1
#
# found https://srath.com/parashara-jyotisa-course-2020-24/ = http://www.srath.com/parashara-jyotisa-course-2020-24 for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com
href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/bondage-freedom , anchor: Bondage Freedom
# appending new url: http://www.srath.com/bondage-freedom click depth: 1
#
# found https://srath.com/bondage-freedom/ = http://www.srath.com/bondage-freedom for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/age-of-sakti/ = http://www.srath.com/age-of-sakti for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com , appending target: http://www.srath.com/age-of-sakti , anchor: Age of Śaktī
# appending new url: http://www.srath.com/age-of-sakti click depth: 1
#
# found https://srath.com/age-of-sakti/ = http://www.srath.com/age-of-sakti for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined external URL http://www.srisaradamath.org/onlinedonationhead.php
#
# declined external URL https://www.youtube.com/watch?v=UsuGp8bvUHs
#
# declined external URL https://overcast.fm/itunes1505029497/raths-jyotish
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@outlook.com
#
# declined external URL http://sohamsa.com
#
# declined external URL http://sohamsa.in
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://dhimanta.com/jspa
#
# declined external URL http://jaiminisutra.com
#
# declined external URL http://parasarahora.com
#
# declined external URL https://srath.in
#
# found /dbc/about-us = http://www.srath.com/dbc/about-us for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com , appending target: http://www.srath.com/dbc/about-us , anchor: About
# appending new url: http://www.srath.com/dbc/about-us click depth: 1
#
# declined external URL http://sohamsa.org/
#
# declined external URL http://thejyotishdigest.com
#
# found https://srath.com/ = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# declined external URL http://sohamsa.com
#
# declined external URL http://sagittariuspublications.com
#
# found /blog = http://www.srath.com/blog for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com , appending target: http://www.srath.com/blog , anchor: Blog
# appending new url: http://www.srath.com/blog click depth: 1
#
# found /contact = http://www.srath.com/contact for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com , appending target: http://www.srath.com/contact , anchor: Contact
# appending new url: http://www.srath.com/contact click depth: 1
#
# declined external URL http://srijagannath.org/
#
# declined external URL http://en.gravatar.com/sarbanirath
#
# declined external URL mailto=sarbanirath@gmail.com
#
# declined url (href in exceptions): callto:+91 9810449850
#
# declined url (href in exceptions): http://www.facebook.com/SanjayRath
#
# declined url (href in exceptions): http://www.twitter.com/sanjayrath
#
# declined external URL https://www.linkedin.com/in/sanjayrath/
#
# declined url (href in exceptions): https://plus.google.com/+sanjayrathSJC
#
# declined url (href in exceptions): #
#
#
# now crawling page: http://www.srath.com/category/about
# status code: 200
#
# declined external URL http://srijagannath.org/
#
# declined url (href in exceptions): #
#
# declined external URL http://sohamsa.com
#
# declined url (href in exceptions): #
#
# declined external URL http://sohamsa.in/
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://thejyotishdigest.com/
#
# declined external URL http://vyasadeva.com
#
# declined external URL http://devaguru.com
#
# declined url (href in exceptions): #
#
# declined external URL http://jaiminisutra.com
#
# declined external URL http://srath.info
#
# declined external URL http://parasarahora.com
#
# declined external URL http://mantrashastra.com
#
# declined external URL http://srath.info
#
# declined external URL http://deva.guru/
#
# declined url (href in exceptions): #
#
# declined external URL http://deva.guru/panchang
#
# declined external URL http://deva.guru/muhurta/
#
# declined url (href in exceptions): https://srath.com/wp-login.php
#
# declined url (href in exceptions): https://srath.com/wp-login.php?action=lostpassword
#
# declined url (href in exceptions): https://srath.com/wp-login.php?action=register
#
# found http://srath.com = http://www.srath.com for href in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com , anchor: Pt. Sanjay Rath
# URL already in URLlist
#
# found http://srath.com = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# found https://srath.com/ = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/about/ = http://www.srath.com/category/about for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/about/ = http://www.srath.com/about for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/about , anchor: Sanjay Rath
# URL already in URLlist
#
# found https://srath.com/rathatreya/ = http://www.srath.com/rathatreya for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/rathatreya , anchor: Rathātreya
# URL already in URLlist
#
# found https://srath.com/para%e1%b9%81para/ = http://www.srath.com/para%e1%b9%81para for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/para%e1%b9%81para , anchor: Paraṁparā
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/ = http://www.srath.com/category/jyoti%e1%b9%a3a for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a , anchor: Jyotiṣa
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/celebrity/ = http://www.srath.com/category/celebrity for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/celebrity , anchor: Celebrity
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/celebrity/india/ = http://www.srath.com/category/celebrity/india for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/celebrity/india , anchor: India
# URL already in URLlist
#
# found https://srath.com/category/celebrity/flim/ = http://www.srath.com/category/celebrity/flim for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/celebrity/flim , anchor: Flim
# URL already in URLlist
#
# found https://srath.com/category/celebrity/usa/ = http://www.srath.com/category/celebrity/usa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/celebrity/usa , anchor: USA
# URL already in URLlist
#
# found https://srath.com/category/celebrity/politics/ = http://www.srath.com/category/celebrity/politics for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/celebrity/politics , anchor: Politics
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/amateur/ = http://www.srath.com/category/jyoti%e1%b9%a3a/amateur for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/amateur , anchor: Amateur
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/scholar/ = http://www.srath.com/category/jyoti%e1%b9%a3a/scholar for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/scholar , anchor: Scholar
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/dasa/ = http://www.srath.com/category/jyoti%e1%b9%a3a/dasa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/dasa , anchor: Daśā
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta/ = http://www.srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta , anchor: Gaṇḍānta
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/muhurta/ = http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta , anchor: Muhurta
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/mundane/ = http://www.srath.com/category/jyoti%e1%b9%a3a/mundane for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/mundane , anchor: Mundane
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra/ = http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra , anchor: Nakṣatra
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga , anchor: Pañcāṅga
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa/ = http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa , anchor: Tithī Praveśa
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/varga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/varga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/varga , anchor: Varga
# URL already in URLlist
#
# found https://srath.com/category/misc/jyoti%e1%b9%a3a-gems/ = http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems , anchor: Jyotiṣa Gems
# URL already in URLlist
#
# found https://srath.com/category/misc/vastu/ = http://www.srath.com/category/misc/vastu for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/vastu , anchor: Vāstu
# URL already in URLlist
#
# found https://srath.com/category/learn/ = http://www.srath.com/category/learn for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/learn , anchor: Learn
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/announcements/ = http://www.srath.com/category/announcements for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/announcements , anchor: Announcements
# URL already in URLlist
#
# found https://srath.com/category/learn/workshops/ = http://www.srath.com/category/learn/workshops for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/learn/workshops , anchor: Workshops
# URL already in URLlist
#
# found https://srath.com/category/spirituality/ = http://www.srath.com/category/spirituality for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/spirituality , anchor: Spirit
# URL already in URLlist
#
# found https://srath.com/category/misc/ = http://www.srath.com/category/misc for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc , anchor: Misc
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/misc/media/video/ = http://www.srath.com/category/misc/media/video for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/media/video , anchor: Video
# URL already in URLlist
#
# found https://srath.com/category/misc/media/ = http://www.srath.com/category/misc/media for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/media , anchor: Media
# URL already in URLlist
#
# found https://srath.com/category/misc/raphsody/ = http://www.srath.com/category/misc/raphsody for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/raphsody , anchor: Raphsody
# URL already in URLlist
#
# found https://srath.com/category/misc/resources/ = http://www.srath.com/category/misc/resources for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/misc/resources , anchor: Resources
# URL already in URLlist
#
# found https://srath.com/category/your-futurology/ = http://www.srath.com/category/your-futurology for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/about , appending target: http://www.srath.com/category/your-futurology , anchor: Your Futurology
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# ...
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/celebrity/flim , anchor: Flim
# URL already in URLlist
#
# found https://srath.com/category/celebrity/usa/ = http://www.srath.com/category/celebrity/usa for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/category/celebrity/politics/ = http://www.srath.com/category/celebrity/politics for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/celebrity/politics , anchor: Politics
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/amateur/ = http://www.srath.com/category/jyoti%e1%b9%a3a/amateur for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/amateur , anchor: Amateur
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/scholar/ = http://www.srath.com/category/jyoti%e1%b9%a3a/scholar for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/scholar , anchor: Scholar
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/dasa/ = http://www.srath.com/category/jyoti%e1%b9%a3a/dasa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/dasa , anchor: Daśā
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta/ = http://www.srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta , anchor: Gaṇḍānta
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/muhurta/ = http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta , anchor: Muhurta
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/mundane/ = http://www.srath.com/category/jyoti%e1%b9%a3a/mundane for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/mundane , anchor: Mundane
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra/ = http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra , anchor: Nakṣatra
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga , anchor: Pañcāṅga
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa/ = http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa , anchor: Tithī Praveśa
# URL already in URLlist
#
# found https://srath.com/category/jyoti%e1%b9%a3a/varga/ = http://www.srath.com/category/jyoti%e1%b9%a3a/varga for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/jyoti%e1%b9%a3a/varga , anchor: Varga
# URL already in URLlist
#
# found https://srath.com/category/misc/jyoti%e1%b9%a3a-gems/ = http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems , anchor: Jyotiṣa Gems
# URL already in URLlist
#
# found https://srath.com/category/misc/vastu/ = http://www.srath.com/category/misc/vastu for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/vastu , anchor: Vāstu
# URL already in URLlist
#
# found https://srath.com/category/learn/ = http://www.srath.com/category/learn for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/learn , anchor: Learn
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/announcements/ = http://www.srath.com/category/announcements for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/announcements , anchor: Announcements
# URL already in URLlist
#
# found https://srath.com/category/learn/workshops/ = http://www.srath.com/category/learn/workshops for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/learn/workshops , anchor: Workshops
# URL already in URLlist
#
# found https://srath.com/category/spirituality/ = http://www.srath.com/category/spirituality for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/spirituality , anchor: Spirit
# URL already in URLlist
#
# found https://srath.com/category/misc/ = http://www.srath.com/category/misc for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc , anchor: Misc
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/category/misc/media/video/ = http://www.srath.com/category/misc/media/video for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/media/video , anchor: Video
# URL already in URLlist
#
# found https://srath.com/category/misc/media/ = http://www.srath.com/category/misc/media for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/media , anchor: Media
# URL already in URLlist
#
# found https://srath.com/category/misc/raphsody/ = http://www.srath.com/category/misc/raphsody for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/raphsody , anchor: Raphsody
# URL already in URLlist
#
# found https://srath.com/category/misc/resources/ = http://www.srath.com/category/misc/resources for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/misc/resources , anchor: Resources
# URL already in URLlist
#
# found https://srath.com/category/your-futurology/ = http://www.srath.com/category/your-futurology for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/category/your-futurology , anchor: Your Futurology
# URL already in URLlist
#
# declined url (href in exceptions): #
#
# found https://srath.com/about-future/ = http://www.srath.com/about-future for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/about-future , anchor: About Your Future
# URL already in URLlist
#
# found https://srath.com/the-process/ = http://www.srath.com/the-process for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/the-process , anchor: The Process
# URL already in URLlist
#
# found https://srath.com/standard-60min/ = http://www.srath.com/standard-60min for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/standard-60min , anchor: Standard 60min
# URL already in URLlist
#
# found https://srath.com/quick-consult/ = http://www.srath.com/quick-consult for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/quick-consult , anchor: Short Meeting 30m
# URL already in URLlist
#
# found https://srath.com/standard-india/ = http://www.srath.com/standard-india for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/standard-india , anchor: Standard India 60m
# URL already in URLlist
#
# found https://srath.com/quick-india-consult/ = http://www.srath.com/quick-india-consult for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/quick-india-consult , anchor: Short India 30m
# URL already in URLlist
#
# declined url (href in exceptions): #g-search-search-9995
#
# declined external URL https://automattic.com/cookies/
#
# found https://srath.com/barak-obama/ = http://www.srath.com/barak-obama for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/barak-obama , anchor: Barrack Obama
# appending new url: http://www.srath.com/barak-obama click depth: 2
#
# found https://srath.com/barak-obama/ = http://www.srath.com/barak-obama for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/barak-obama/ = http://www.srath.com/barak-obama for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/franklin-delano-roosevelt/ = http://www.srath.com/franklin-delano-roosevelt for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/franklin-delano-roosevelt , anchor: Franklin Delano Roosevelt
# appending new url: http://www.srath.com/franklin-delano-roosevelt click depth: 2
#
# found https://srath.com/franklin-delano-roosevelt/ = http://www.srath.com/franklin-delano-roosevelt for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/franklin-delano-roosevelt/ = http://www.srath.com/franklin-delano-roosevelt for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/bill-clinton/ = http://www.srath.com/bill-clinton for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/bill-clinton , anchor: Bill Clinton
# appending new url: http://www.srath.com/bill-clinton click depth: 2
#
# found https://srath.com/bill-clinton/ = http://www.srath.com/bill-clinton for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# found https://srath.com/bill-clinton/ = http://www.srath.com/bill-clinton for href.startswith(x) for x in alternativeDomains
# duplicate target link
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): #
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined external URL https://api.whatsapp.com/send?phone=919818593935
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:VedicReading@SRath.com
#
# found https://srath.com/files/reading/vedic_reading_form.rtf = http://www.srath.com/files/reading/vedic_reading_form.rtf for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/files/reading/vedic_reading_form.rtf , anchor: Rich Text Format
# URL already in URLlist
#
# found https://srath.com/files/reading/vedic_reading_form.doc = http://www.srath.com/files/reading/vedic_reading_form.doc for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/files/reading/vedic_reading_form.doc , anchor: Word - DOC
# URL already in URLlist
#
# found https://srath.com/files/reading/vedic_reading_form.docx = http://www.srath.com/files/reading/vedic_reading_form.docx for href.startswith(x) for x in alternativeDomains
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/files/reading/vedic_reading_form.docx , anchor: Word - DOCX
# URL already in URLlist
#
# declined url (href in exceptions): https://srath.com/files/reading/vedic_reading_form.pdf
#
# declined external URL http://www.srisaradamath.org/onlinedonationhead.php
#
# declined external URL https://www.youtube.com/watch?v=UsuGp8bvUHs
#
# declined external URL https://overcast.fm/itunes1505029497/raths-jyotish
#
# declined url (href in exceptions): mailto:sanjayrath@gmail.com
#
# declined url (href in exceptions): mailto:sanjayrath@outlook.com
#
# declined external URL http://sohamsa.com
#
# declined external URL http://sohamsa.in
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://sagittariuspublications.com
#
# declined external URL http://dhimanta.com/jspa
#
# declined external URL http://jaiminisutra.com
#
# declined external URL http://parasarahora.com
#
# declined external URL https://srath.in
#
# found /dbc/about-us = http://www.srath.com/dbc/about-us for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/dbc/about-us , anchor: About
# URL already in URLlist
#
# declined external URL http://sohamsa.org/
#
# declined external URL http://thejyotishdigest.com
#
# found https://srath.com/ = http://www.srath.com for href in alternativeDomains
# duplicate target link
#
# declined external URL http://sohamsa.com
#
# declined external URL http://sagittariuspublications.com
#
# found /blog = http://www.srath.com/blog for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/blog , anchor: Blog
# URL already in URLlist
#
# found /contact = http://www.srath.com/contact for len(href)>1 and href[0] == / and not any(x in href for x in externalURLKeywords
# for source: http://www.srath.com/category/celebrity/usa , appending target: http://www.srath.com/contact , anchor: Contact
# URL already in URLlist
#
# declined external URL http://srijagannath.org/
#
# declined external URL http://en.gravatar.com/sarbanirath
#
# declined external URL mailto=sarbanirath@gmail.com
#
# declined url (href in exceptions): callto:+91 9810449850
#
# declined url (href in exceptions): http://www.facebook.com/SanjayRath
#
# declined url (href in exceptions): http://www.twitter.com/sanjayrath
#
# declined external URL https://www.linkedin.com/in/sanjayrath/
#
# declined url (href in exceptions): https://plus.google.com/+sanjayrathSJC
#
# declined url (href in exceptions): #
# --- 20.70033574104309 seconds ---

# %%
pageInfoDF = pd.DataFrame.from_dict({(i): pageDict[i] 
                           for i in pageDict.keys()},
                       orient='index')
pageInfoDF.head(4000)
# Out:
#                                                                                             title  \
# http://www.srath.com                                 Sanjay Rath – Vedic Astrology & Spirituality
# http://www.srath.com/1134                                                                     NaN
# http://www.srath.com/16-bosepara-lane                                                         NaN
# http://www.srath.com/182                                                                      NaN
# http://www.srath.com/2010-2                                                                   NaN
# http://www.srath.com/2010/12/bill-clinton/billc...                                            NaN
# http://www.srath.com/2010/12/bill-clinton/billc...                                            NaN
# http://www.srath.com/2010/12/bill-clinton/presi...                                            NaN
# http://www.srath.com/2010/12/bjp-vajpayee-swear...                                            NaN
# http://www.srath.com/2010/12/bjp-vajpayee-swear...                                            NaN
# http://www.srath.com/2010/12/bjp-vajpayee-swear...                                            NaN
# http://www.srath.com/2010/12/bjp-vajpayee-swear...                                            NaN
# http://www.srath.com/2010/12/bjp-vajpayee-swear...                                            NaN
# http://www.srath.com/2010/12/dr-murli-manohar-j...                                            NaN
# http://www.srath.com/2010/12/dr-murli-manohar-j...                                            NaN
# http://www.srath.com/2010/12/dr-murli-manohar-j...                                            NaN
# http://www.srath.com/2010/12/dr-murli-manohar-j...                                            NaN
# http://www.srath.com/2010/12/dvisaptati-sama-da...                                            NaN
# http://www.srath.com/2010/12/franklin-delano-ro...                                            NaN
# http://www.srath.com/2010/12/franklin-delano-ro...                                            NaN
# http://www.srath.com/2010/12/franklin-delano-ro...                                            NaN
# http://www.srath.com/2010/12/franklin-delano-ro...                                            NaN
# http://www.srath.com/2010/12/india-tithi-praves...                                            NaN
# http://www.srath.com/2010/12/india-tithi-praves...                                            NaN
# http://www.srath.com/2010/12/india-tithi-praves...                                            NaN
# http://www.srath.com/2010/12/india-tithi-praves...                                            NaN
# http://www.srath.com/2010/12/introduction-to-va...                                            NaN
# http://www.srath.com/2010/12/kalaignar-dr-karun...                                            NaN
# http://www.srath.com/2010/12/kalaignar-dr-karun...                                            NaN
# http://www.srath.com/2010/12/kalaignar-dr-karun...                                            NaN
# ...                                                                                           ...
# http://www.srath.com/vara-chakra-13-months-13-s...  Vāra Chakra: 13 Months 13 Signs – Sanjay Rath
# http://www.srath.com/varga-chakra                                                             NaN
# http://www.srath.com/various-ganesha-mantra                  Various Ganesha Mantra – Sanjay Rath
# http://www.srath.com/varu%e1%b9%87a-guardian-of...                                            NaN
# http://www.srath.com/vedic-astrology-the-philos...                                            NaN
# http://www.srath.com/vedic-calendar                                  Vedic Calendar – Sanjay Rath
# http://www.srath.com/vedic-ga%e1%b9%87esa-mantra                                              NaN
# http://www.srath.com/vedic-reading-form                          Vedic Reading Form – Sanjay Rath
# http://www.srath.com/vedic-remedies-in-astrology                                              NaN
# http://www.srath.com/video/KarmaTheory/index.htm                                              NaN
# http://www.srath.com/vijayawada-top-cop-p-s-r-a...                                            NaN
# http://www.srath.com/vimsa%e1%b9%81sa-workshop-...                                            NaN
# http://www.srath.com/vimshottari-dasha-2                       Vimshottari Dasha #2 – Sanjay Rath
# http://www.srath.com/vimsottari-dasa                                Vimśottari Daśā – Sanjay Rath
# http://www.srath.com/vimsottari-udu-dasa                                                      NaN
# http://www.srath.com/vyasa-class-aru%e1%b8%8dha...                                            NaN
# http://www.srath.com/what-is-happening-2011-app...                                            NaN
# http://www.srath.com/what-is-hora-shastra                                                     NaN
# http://www.srath.com/william-h-rehnquist                                                      NaN
# http://www.srath.com/wisdom-of-our-tradition                                                  NaN
# http://www.srath.com/world-view-of-iran                                                       NaN
# http://www.srath.com/wp-login.php                                Log In ‹ Sanjay Rath — WordPress
# http://www.srath.com/wp-login.php?action=jetpac...                                  WordPress.com
# http://www.srath.com/wp-login.php?action=lostpa...        Lost Password ‹ Sanjay Rath — WordPress
# http://www.srath.com/wp-login.php?action=register     Registration Form ‹ Sanjay Rath — WordPress
# http://www.srath.com/wp-login.php?jetpack-sso-s...               Log In ‹ Sanjay Rath — WordPress
# http://www.srath.com/wp-login.php?jetpack-sso-s...               Log In ‹ Sanjay Rath — WordPress
# http://www.srath.com/y-s-rajasekhara-reddy                                                    NaN
# http://www.srath.com/yemen-horoscope                                Yemen Horoscope – Sanjay Rath
# http://www.srath.com/zola-budd                                            Zola Budd – Sanjay Rath
#
#                                                     status_code  clickDepth  \
# http://www.srath.com                                      200.0           0
# http://www.srath.com/1134                                   NaN           3
# http://www.srath.com/16-bosepara-lane                       NaN           3
# http://www.srath.com/182                                    NaN           3
# http://www.srath.com/2010-2                                 NaN           3
# http://www.srath.com/2010/12/bill-clinton/billc...          NaN           3
# http://www.srath.com/2010/12/bill-clinton/billc...          NaN           3
# http://www.srath.com/2010/12/bill-clinton/presi...          NaN           3
# http://www.srath.com/what-is-happening-2011-app...             NaN
# http://www.srath.com/what-is-hora-shastra                      NaN
# http://www.srath.com/william-h-rehnquist                       NaN
# http://www.srath.com/wisdom-of-our-tradition                   NaN
# http://www.srath.com/world-view-of-iran                        NaN
# http://www.srath.com/wp-login.php                              6.0
# http://www.srath.com/wp-login.php?action=jetpac...             0.0
# http://www.srath.com/wp-login.php?action=lostpa...             3.0
# http://www.srath.com/wp-login.php?action=register              3.0
# http://www.srath.com/wp-login.php?jetpack-sso-s...             5.0
# http://www.srath.com/wp-login.php?jetpack-sso-s...             5.0
# http://www.srath.com/y-s-rajasekhara-reddy                     NaN
# http://www.srath.com/yemen-horoscope                          48.0
# http://www.srath.com/zola-budd                                48.0
#
# [466 rows x 5 columns]

# %%
Links = {}
Links['source'] = sourceList
Links['target'] = targetList
Links['anchor'] = anchorList
Links['href'] = hrefList
linkInfoDF = pd.DataFrame(Links)
linkInfoDF.head(25000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-cf00faa9d596> in <module>
#       3 Links['target'] = targetList
#       4 Links['anchor'] = anchorList
# ----> 5 Links['href'] = hrefList
#       6 linkInfoDF = pd.DataFrame(Links)
#       7 linkInfoDF.head(25000)
#
# NameError: name 'hrefList' is not defined

# %%
urlName = rootURL
urlName = urlName.replace("http://","")
urlName = urlName.replace("https://","")
urlName = urlName.replace("www.","")
# urlName = urlName.replace("/","")
linkInfoDF.to_csv(r'C:\Users\hiren\crawly\links_news'+urlName+'.csv')
pageInfoDF.to_csv(r'C:\Users\hiren\crawly\pages_news'+urlName+'.csv')

# %%
urlList
# Out:
# ['http://www.srath.com',
#  'http://www.srath.com/wp-login.php',
#  'http://www.srath.com/wp-login.php?action=lostpassword',
#  'http://www.srath.com/wp-login.php?action=register',
#  'http://www.srath.com/category/about',
#  'http://www.srath.com/about',
#  'http://www.srath.com/rathatreya',
#  'http://www.srath.com/para%e1%b9%81para',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a',
#  'http://www.srath.com/category/celebrity',
#  'http://www.srath.com/category/celebrity/india',
#  'http://www.srath.com/category/celebrity/flim',
#  'http://www.srath.com/category/celebrity/usa',
#  'http://www.srath.com/category/celebrity/politics',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/amateur',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/scholar',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/dasa',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/ga%e1%b9%87%e1%b8%8danta',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/muhurta',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/mundane',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/panca%e1%b9%85ga',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/tithi-pravesa',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/varga',
#  'http://www.srath.com/category/misc/jyoti%e1%b9%a3a-gems',
#  'http://www.srath.com/category/misc/vastu',
#  'http://www.srath.com/category/learn',
#  'http://www.srath.com/category/announcements',
#  'http://www.srath.com/category/learn/workshops',
#  'http://www.srath.com/category/spirituality',
#  'http://www.srath.com/category/misc',
#  'http://www.srath.com/category/misc/media/video',
#  'http://www.srath.com/category/misc/media',
#  'http://www.srath.com/category/misc/raphsody',
#  'http://www.srath.com/category/misc/resources',
#  'http://www.srath.com/category/your-futurology',
#  'http://www.srath.com/about-future',
#  'http://www.srath.com/the-process',
#  'http://www.srath.com/standard-60min',
#  'http://www.srath.com/quick-consult',
#  'http://www.srath.com/standard-india',
#  'http://www.srath.com/quick-india-consult',
#  'http://www.srath.com/files/reading/vedic_reading_form.rtf',
#  'http://www.srath.com/files/reading/vedic_reading_form.doc',
#  'http://www.srath.com/files/reading/vedic_reading_form.docx',
#  'http://www.srath.com/msp-ii-graha-devata',
#  'http://www.srath.com/parashara-jyotisa-course-2020-24',
#  'http://www.srath.com/2019-bava-conference',
#  'http://www.srath.com/mantra-sastra-program',
#  'http://www.srath.com/peoples-republic-of-china',
#  'http://www.srath.com/first-republic-of-china',
#  'http://www.srath.com/finding-guru-and-seeking-knowledge',
#  'http://www.srath.com/curse-of-jupiter-in-sagittarius',
#  'http://www.srath.com/meaning-of-word-jyoti%e1%b9%a3a',
#  'http://www.srath.com/panchanga-intro',
#  'http://www.srath.com/dhana-karaka-workshop',
#  'http://www.srath.com/ny-workshop-on-spiritual-yogas-2017',
#  'http://www.srath.com/solar-eclipse-2014',
#  'http://www.srath.com/lunar-eclipse-of-2014',
#  'http://www.srath.com/eclipse-factor',
#  'http://www.srath.com/devaguru-b%e1%b9%9bhaspati',
#  'http://www.srath.com/lineage',
#  'http://www.srath.com/narendra-modi-2014-chart',
#  'http://www.srath.com/priyanka-chopra',
#  'http://www.srath.com/dr-rajendra-prasad',
#  'http://www.srath.com/super-star-rajesh-khanna',
#  'http://www.srath.com/kejriwal-government-ii',
#  'http://www.srath.com/krs-marriage-12h',
#  'http://www.srath.com/deep-introduction-to-nakshatras',
#  'http://www.srath.com/b%e1%b9%9bhaspati-kavacha-mantra',
#  'http://www.srath.com/sleep-direction',
#  'http://www.srath.com/oscar-pistorius-found-guilty-of-murder',
#  'http://www.srath.com/sri-rudras-krishna-mantra',
#  'http://www.srath.com/sri-narasimha-mars',
#  'http://www.srath.com/sapta-sloki-gita',
#  'http://www.srath.com/bondage-freedom',
#  'http://www.srath.com/age-of-sakti',
#  'http://www.srath.com/dbc/about-us',
#  'http://www.srath.com/blog',
#  'http://www.srath.com/contact',
#  'http://www.srath.com/wp-login.php?action=jetpack-sso',
#  'http://www.srath.com/wp-login.php?jetpack-sso-show-default-form=1',
#  'http://www.srath.com/wp-login.php?jetpack-sso-show-default-form=0',
#  'http://www.srath.com/defining-the-ayana',
#  'http://www.srath.com/sama-saptaka-concept',
#  'http://www.srath.com/karma-and-freewill',
#  'http://www.srath.com/gunas-in-towns-and-villages',
#  'http://www.srath.com/soha%e1%b9%81sa',
#  'http://www.srath.com/category/about/page/2',
#  'http://www.srath.com/series/about',
#  'http://www.srath.com/sarbanirath',
#  'http://www.srath.com/parents',
#  'http://www.srath.com/beautiful-kids',
#  'http://www.srath.com/guru-vandana',
#  'http://www.srath.com/?attachment_id=',
#  'http://www.srath.com/about/?share=facebook',
#  'http://www.srath.com/about/?share=twitter',
#  'http://www.srath.com/about/?share=jetpack-whatsapp',
#  'http://www.srath.com/about/?share=telegram',
#  'http://www.srath.com/about/?share=linkedin',
#  'http://www.srath.com/about/?share=pinterest',
#  'http://www.srath.com/about/?share=reddit',
#  'http://www.srath.com/about/?share=tumblr',
#  'http://www.srath.com/about/?share=pocket',
#  'http://www.srath.com/about/?share=email',
#  'http://www.srath.com/about/?share=skype',
#  'http://www.srath.com/bjp-vajpayee-swearing-in-1999',
#  'http://www.srath.com/bjp-vajpayee-swearing-in-1998',
#  'http://www.srath.com/shiv-sena-party',
#  'http://www.srath.com/category/celebrity/politics/page/2',
#  'http://www.srath.com/rahu-and-eighth-house',
#  'http://www.srath.com/ma%e1%b9%85galika-do%e1%b9%a3a',
#  'http://www.srath.com/arudha-pada-images-of-world',
#  'http://www.srath.com/argala-planetary-intervention',
#  'http://www.srath.com/tattva-dristi',
#  'http://www.srath.com/hora-roots-of-jyotish',
#  'http://www.srath.com/brahma-vidya-yuga-sub-cycles',
#  'http://www.srath.com/sambandha2',
#  'http://www.srath.com/vimshottari-dasha-2',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/amateur/page/2',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/amateur/page/3',
#  'http://www.srath.com/netraha-yoga-illustrations',
#  'http://www.srath.com/complexity-of-jaimini-sutra',
#  'http://www.srath.com/jupiter-bhava-strong-or-weak',
#  'http://www.srath.com/darapada-and-upapada',
#  'http://www.srath.com/karakamsa-and-natural-zodiac',
#  'http://www.srath.com/eight-sign-zodiac',
#  'http://www.srath.com/national-finance',
#  'http://www.srath.com/trimsamsa-d-30-chart',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/scholar/page/2',
#  'http://www.srath.com/introduction-01',
#  'http://www.srath.com/preface',
#  'http://www.srath.com/shula-dasha',
#  'http://www.srath.com/vimsottari-dasa',
#  'http://www.srath.com/naisargika-dasha',
#  'http://www.srath.com/dvisaptati-sama-dasa',
#  'http://www.srath.com/zola-budd',
#  'http://www.srath.com/bruce-hammerslough',
#  'http://www.srath.com/albert-al-gore-jr',
#  'http://www.srath.com/ingeborg-bachmann',
#  'http://www.srath.com/darryl-sittler',
#  'http://www.srath.com/charlie-sheen',
#  'http://www.srath.com/ga%e1%b9%87%e1%b8%8danta-anthony-hopkins',
#  'http://www.srath.com/ga%e1%b9%87%e1%b8%8danta',
#  'http://www.srath.com/muhurta-definition',
#  'http://www.srath.com/muhurta',
#  'http://www.srath.com/predicting-rain',
#  'http://www.srath.com/yemen-horoscope',
#  'http://www.srath.com/eclipse-hits-astrologers-doctors-etc',
#  'http://www.srath.com/greek-fire-of-2008-hasnt-stopped',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/mundane/page/2',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/mundane/page/3',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/mundane/page/4',
#  'http://www.srath.com/series/nak%e1%b9%a3atra',
#  'http://www.srath.com/sun-in-k%e1%b9%9bttika',
#  'http://www.srath.com/sun-in-bhara%e1%b9%87i',
#  'http://www.srath.com/sun-in-asvini',
#  'http://www.srath.com/naksatras-in-disease',
#  'http://www.srath.com/nakshatra-articles',
#  'http://www.srath.com/nakshatra-shakti',
#  'http://www.srath.com/nakshatra-basics',
#  'http://www.srath.com/nakshatra-tables',
#  'http://www.srath.com/nakshatra-division',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/nak%e1%b9%a3atra/page/2',
#  'http://www.srath.com/vedic-calendar',
#  'http://www.srath.com/vara-chakra-13-months-13-signs',
#  'http://www.srath.com/tithi-pravesha',
#  'http://www.srath.com/india-tithi-pravesh-2008',
#  'http://www.srath.com/drekkana-reckoning-and-rishis',
#  'http://www.srath.com/principles-of-divisional-charts',
#  'http://www.srath.com/thirty-six-rajayoga-gemstones',
#  'http://www.srath.com/surya-yantra',
#  'http://www.srath.com/tantrika-navagraha-mantra',
#  'http://www.srath.com/22-jyoti%e1%b9%a3a-gems',
#  'http://www.srath.com/introduction-to-vastu',
#  'http://www.srath.com/series/bala-jyotisa',
#  'http://www.srath.com/sfo-vimsottari-dasa-workshop',
#  'http://www.srath.com/syf-conference-2017',
#  'http://www.srath.com/bava-18th-international-conference',
#  'http://www.srath.com/pjc-2016-admissions',
#  'http://www.srath.com/jyoti%e1%b9%a3a-workshop-on-family',
#  'http://www.srath.com/category/learn/page/2',
#  'http://www.srath.com/category/learn/page/3',
#  'http://www.srath.com/category/learn/page/4',
#  'http://www.srath.com/bava-2017',
#  'http://www.srath.com/parashara-jyotisa-course-2017',
#  'http://www.srath.com/category/announcements/page/2',
#  'http://www.srath.com/category/announcements/page/3',
#  'http://www.srath.com/marriage-and-relationships-workshops',
#  'http://www.srath.com/bava-17th-international-conference',
#  'http://www.srath.com/cva-2014-conference',
#  'http://www.srath.com/category/learn/workshops/page/2',
#  'http://www.srath.com/om-hrim-ritam-mantra',
#  'http://www.srath.com/multiple-hanuman-jayanti',
#  'http://www.srath.com/graha-purascara%e1%b9%87a-prayoga%e1%b8%a5',
#  'http://www.srath.com/various-ganesha-mantra',
#  'http://www.srath.com/category/spirituality/page/2',
#  'http://www.srath.com/category/spirituality/page/3',
#  'http://www.srath.com/category/spirituality/page/4',
#  'http://www.srath.com/category/spirituality/page/5',
#  'http://www.srath.com/category/spirituality/page/6',
#  'http://www.srath.com/flight-mh370-disaster',
#  'http://www.srath.com/murdered-due-to-hairstyle',
#  'http://www.srath.com/category/misc/page/2',
#  'http://www.srath.com/category/misc/page/3',
#  'http://www.srath.com/category/misc/page/4',
#  'http://www.srath.com/category/misc/page/5',
#  'http://www.srath.com/sixteen-divisions',
#  'http://www.srath.com/putins-chart',
#  'http://www.srath.com/krishna-astakam',
#  'http://www.srath.com/prayers',
#  'http://www.srath.com/mind-trembles-for-a-vision-of-hari',
#  'http://www.srath.com/ae-malik-tere-bande-ha%e1%b9%81',
#  'http://www.srath.com/untitled-video-2',
#  'http://www.srath.com/untitled-video',
#  'http://www.srath.com/category/misc/media/page/2',
#  'http://www.srath.com/kalis-anger',
#  'http://www.srath.com/pranab-mukherjee-next-president',
#  'http://www.srath.com/value-of-tolerance',
#  'http://www.srath.com/jhd-country',
#  'http://www.srath.com/resources',
#  'http://www.srath.com/vedic-reading-form',
#  'http://www.srath.com/order-confirmed',
#  'http://www.srath.com/about-future/?share=facebook',
#  'http://www.srath.com/about-future/?share=twitter',
#  'http://www.srath.com/about-future/?share=jetpack-whatsapp',
#  'http://www.srath.com/about-future/?share=telegram',
#  'http://www.srath.com/about-future/?share=linkedin',
#  'http://www.srath.com/about-future/?share=pinterest',
#  'http://www.srath.com/about-future/?share=reddit',
#  'http://www.srath.com/about-future/?share=tumblr',
#  'http://www.srath.com/about-future/?share=pocket',
#  'http://www.srath.com/about-future/?share=email',
#  'http://www.srath.com/about-future/?share=skype',
#  'http://www.srath.com/the-process/?share=facebook',
#  'http://www.srath.com/the-process/?share=twitter',
#  'http://www.srath.com/the-process/?share=jetpack-whatsapp',
#  'http://www.srath.com/the-process/?share=telegram',
#  'http://www.srath.com/the-process/?share=linkedin',
#  'http://www.srath.com/the-process/?share=pinterest',
#  'http://www.srath.com/the-process/?share=reddit',
#  'http://www.srath.com/the-process/?share=tumblr',
#  'http://www.srath.com/the-process/?share=pocket',
#  'http://www.srath.com/the-process/?share=email',
#  'http://www.srath.com/the-process/?share=skype',
#  'http://www.srath.com/standard-60min/?share=facebook',
#  'http://www.srath.com/standard-60min/?share=twitter',
#  'http://www.srath.com/standard-60min/?share=jetpack-whatsapp',
#  'http://www.srath.com/standard-60min/?share=telegram',
#  'http://www.srath.com/standard-60min/?share=linkedin',
#  'http://www.srath.com/standard-60min/?share=pinterest',
#  'http://www.srath.com/standard-60min/?share=reddit',
#  'http://www.srath.com/standard-60min/?share=tumblr',
#  'http://www.srath.com/standard-60min/?share=pocket',
#  'http://www.srath.com/standard-60min/?share=email',
#  'http://www.srath.com/standard-60min/?share=skype',
#  'http://www.srath.com/sriguruji?call',
#  'http://www.srath.com/quick-consult/?share=facebook',
#  'http://www.srath.com/quick-consult/?share=twitter',
#  'http://www.srath.com/quick-consult/?share=jetpack-whatsapp',
#  'http://www.srath.com/quick-consult/?share=telegram',
#  'http://www.srath.com/quick-consult/?share=linkedin',
#  'http://www.srath.com/quick-consult/?share=pinterest',
#  'http://www.srath.com/quick-consult/?share=reddit',
#  'http://www.srath.com/quick-consult/?share=tumblr',
#  'http://www.srath.com/quick-consult/?share=pocket',
#  'http://www.srath.com/quick-consult/?share=email',
#  'http://www.srath.com/quick-consult/?share=skype',
#  'http://www.srath.com/reading/01/standard-60min/attachment/hamsa-hand',
#  'http://www.srath.com/standard-india/?share=facebook',
#  'http://www.srath.com/standard-india/?share=twitter',
#  'http://www.srath.com/standard-india/?share=jetpack-whatsapp',
#  'http://www.srath.com/standard-india/?share=telegram',
#  'http://www.srath.com/standard-india/?share=linkedin',
#  'http://www.srath.com/standard-india/?share=pinterest',
#  'http://www.srath.com/standard-india/?share=reddit',
#  'http://www.srath.com/standard-india/?share=tumblr',
#  'http://www.srath.com/standard-india/?share=pocket',
#  'http://www.srath.com/standard-india/?share=email',
#  'http://www.srath.com/standard-india/?share=skype',
#  'http://www.srath.com/quick-india-consult/?share=facebook',
#  'http://www.srath.com/quick-india-consult/?share=twitter',
#  'http://www.srath.com/quick-india-consult/?share=jetpack-whatsapp',
#  'http://www.srath.com/quick-india-consult/?share=telegram',
#  'http://www.srath.com/quick-india-consult/?share=linkedin',
#  'http://www.srath.com/quick-india-consult/?share=pinterest',
#  'http://www.srath.com/quick-india-consult/?share=reddit',
#  'http://www.srath.com/quick-india-consult/?share=tumblr',
#  'http://www.srath.com/quick-india-consult/?share=pocket',
#  'http://www.srath.com/quick-india-consult/?share=email',
#  'http://www.srath.com/quick-india-consult/?share=skype',
#  'http://www.srath.com/msp-ii-graha-devata/?share=facebook',
#  'http://www.srath.com/notre-dame-fire/?share=tumblr',
#  'http://www.srath.com/notre-dame-fire/?share=pocket',
#  'http://www.srath.com/notre-dame-fire/?share=email',
#  'http://www.srath.com/notre-dame-fire/?share=skype',
#  'http://www.srath.com/mula-dasa/?share=facebook',
#  'http://www.srath.com/mula-dasa/?share=twitter',
#  'http://www.srath.com/mula-dasa/?share=jetpack-whatsapp',
#  'http://www.srath.com/mula-dasa/?share=telegram',
#  'http://www.srath.com/mula-dasa/?share=linkedin',
#  'http://www.srath.com/mula-dasa/?share=pinterest',
#  'http://www.srath.com/mula-dasa/?share=reddit',
#  'http://www.srath.com/mula-dasa/?share=tumblr',
#  'http://www.srath.com/mula-dasa/?share=pocket',
#  'http://www.srath.com/mula-dasa/?share=email',
#  'http://www.srath.com/mula-dasa/?share=skype',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=facebook',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=twitter',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=jetpack-whatsapp',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=telegram',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=linkedin',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=pinterest',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=reddit',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=tumblr',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=pocket',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=email',
#  'http://www.srath.com/asvini-nak%e1%b9%a3atra-planets/?share=skype',
#  'http://www.srath.com/series/isis-terror',
#  'http://www.srath.com/isis-caliphate/?share=facebook',
#  'http://www.srath.com/isis-caliphate/?share=twitter',
#  'http://www.srath.com/isis-caliphate/?share=jetpack-whatsapp',
#  'http://www.srath.com/isis-caliphate/?share=telegram',
#  'http://www.srath.com/isis-caliphate/?share=linkedin',
#  'http://www.srath.com/isis-caliphate/?share=pinterest',
#  'http://www.srath.com/isis-caliphate/?share=reddit',
#  'http://www.srath.com/isis-caliphate/?share=tumblr',
#  'http://www.srath.com/isis-caliphate/?share=pocket',
#  'http://www.srath.com/isis-caliphate/?share=email',
#  'http://www.srath.com/isis-caliphate/?share=skype',
#  'http://www.srath.com/isis-lagna/?share=facebook',
#  'http://www.srath.com/isis-lagna/?share=twitter',
#  'http://www.srath.com/isis-lagna/?share=jetpack-whatsapp',
#  'http://www.srath.com/isis-lagna/?share=telegram',
#  'http://www.srath.com/isis-lagna/?share=linkedin',
#  'http://www.srath.com/isis-lagna/?share=pinterest',
#  'http://www.srath.com/isis-lagna/?share=reddit',
#  'http://www.srath.com/isis-lagna/?share=tumblr',
#  'http://www.srath.com/isis-lagna/?share=pocket',
#  'http://www.srath.com/isis-lagna/?share=email',
#  'http://www.srath.com/isis-lagna/?share=skype',
#  'http://www.srath.com/tanzania-black-magic',
#  'http://www.srath.com/melbourne-shock',
#  'http://www.srath.com/sloviansk',
#  'http://www.srath.com/crimea-the-beginning',
#  'http://www.srath.com/ukraine-crisis',
#  'http://www.srath.com/world-view-of-iran',
#  'http://www.srath.com/iran-islamic-republic',
#  'http://www.srath.com/chelyabinsk-meteor',
#  'http://www.srath.com/scope-of-jyoti%e1%b9%a3a',
#  'http://www.srath.com/obama-wins-re-election',
#  'http://www.srath.com/series/naraya%e1%b9%87a-dasa',
#  'http://www.srath.com/atmakaraka-ii-bhagavat-gita',
#  'http://www.srath.com/atmakaraka-karakamsa',
#  'http://www.srath.com/bava-13th-annual-conference-2011',
#  'http://www.srath.com/dharma-marriage',
#  'http://www.srath.com/medical-astrology-i',
#  'http://www.srath.com/category/jyoti%e1%b9%a3a/page/10',
#  'http://www.srath.com/sambandha',
#  'http://www.srath.com/bha-chakra-the-zodiac',
#  'http://www.srath.com/sun-and-moon-in-life',
#  'http://www.srath.com/vedic-astrology-the-philosophy',
#  'http://www.srath.com/introduction-to-vedic-astrology',
#  'http://www.srath.com/what-is-hora-shastra',
#  'http://www.srath.com/elections-2009',
#  'http://www.srath.com/george-harrison',
#  'http://www.srath.com/narayana-dasa-extracts',
#  'http://www.srath.com/jyoti%e1%b9%a3a/mundane/ukraine-crisis',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=facebook',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=twitter',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=jetpack-whatsapp',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=telegram',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=linkedin',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=pinterest',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=reddit',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=tumblr',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=pocket',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=email',
#  'http://www.srath.com/ukraine-un-peace-deal/?share=skype',
#  'http://www.srath.com/celebrity/india/kejriwal-kollapse',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=facebook',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=twitter',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=jetpack-whatsapp',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=telegram',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=linkedin',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=pinterest',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=reddit',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=tumblr',
#  'http://www.srath.com/kiran-bedi-next-cm/?share=pocket',
#  ...]

# %%
len(urlList)
# Out:
# 143

# %%
a = ['a', 'b', 'c']
b = ['p', 'a', 'r']
c = "hapay"
# if any(x in c for x in a) and not any(x in c for x in b):
#     print("true")
# else:
#     print("false")
if any(x in a for x in b):
    print(a)
else:
    print(b)
# Out:
# ['a', 'b', 'c']
